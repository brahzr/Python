# %% [markdown]
# # Sympy

# %% [markdown]
# 1. Install (first time)

# %%
pip install sympy  #internet

# %% [markdown]
# 2. Import

# %%
import sympy

# %%
from sympy import * #import all functions inside sympy

# %%
x = symbols("x")

# %%
f = 2*x**4+5*x**3+3*x**2-9*x+4

# %%
f
# Out:
# 2*x**4 + 5*x**3 + 3*x**2 - 9*x + 4

# %% [markdown]
# ### derivetive الاشتقاق

# %%
diff(f,x)
# Out:
# 8*x**3 + 15*x**2 + 6*x - 9

# %% [markdown]
# ### التكامل

# %%
integrate(f,x)
# Out:
# 2*x**5/5 + 5*x**4/4 + x**3 - 9*x**2/2 + 4*x

# %% [markdown]
# **f * x**

# %%
f * x
# Out:
# x*(2*x**4 + 5*x**3 + 3*x**2 - 9*x + 4)

# %% [markdown]
# ### النشر

# %%
expand(f*x)
# Out:
# 2*x**5 + 5*x**4 + 3*x**3 - 9*x**2 + 4*x

# %% [markdown]
# ### التحليل

# %%
factor(f*x)
# Out:
# x*(2*x**4 + 5*x**3 + 3*x**2 - 9*x + 4)

# %%
x,y = symbols("x,y")

# %%
g = 7*x**6 - 3*y**2 + 5

# %%
g
# Out:
# 7*x**6 - 3*y**2 + 5

# %%
h = 12*cos(x) - log(x**2)

# %%
h
# Out:
# -log(x**2) + 12*cos(x)

# %% [markdown]
# ### النهايات

# %%
limit(h,x,"oo")
# Out:
# -oo

# %%
limit(h,x,"-oo")
# Out:
# -oo

# %%
diff(g,x)
# Out:
# 42*x**5

# %%
diff(g,y)
# Out:
# -6*y

# %%
g_diff_1 = diff(g,y)

# %%
diff(g_diff_1,y)
# Out:
# -6

# %% [markdown]
# ### المعادلات الصفرية

# %%
C = x**2 - 4*x + 16

# %%
C
# Out:
# x**2 - 4*x + 16

# %%
solve(C,x)
# Out:
# [2 - 2*sqrt(3)*I, 2 + 2*sqrt(3)*I]

# %%
sqrt(9)
# Out:
# 3

# %%
sqrt(8)
# Out:
# 2*sqrt(2)

# %%
solve(x**2-1,x)
# Out:
# [-1, 1]

# %%
solve(5*x**3 - 12*x**2 + 9*x - 7, x)
# Out:
# [4/5 + (-1/2 - sqrt(3)*I/2)*(11*sqrt(5)/50 + 123/250)**(1/3) + 1/(25*(-1/2 - sqrt(3)*I/2)*(11*sqrt(5)/50 + 123/250)**(1/3)),
#  4/5 + 1/(25*(-1/2 + sqrt(3)*I/2)*(11*sqrt(5)/50 + 123/250)**(1/3)) + (-1/2 + sqrt(3)*I/2)*(11*sqrt(5)/50 + 123/250)**(1/3),
#  1/(25*(11*sqrt(5)/50 + 123/250)**(1/3)) + 4/5 + (11*sqrt(5)/50 + 123/250)**(1/3)]

# %%
4/5 + (-1/2 - sqrt(3)*I/2)*(11*sqrt(5)/50 + 123/250)**(1/3) + 1/(25*(-1/2 - sqrt(3)*I/2)*(11*sqrt(5)/50 + 123/250)**(1/3))
# Out:
# 0.8 + (-0.5 - sqrt(3)*I/2)*(11*sqrt(5)/50 + 0.492)**0.333333333333333 + 1/((-12.5 - 25*sqrt(3)*I/2)*(11*sqrt(5)/50 + 0.492)**0.333333333333333)

# %%
import math

# %%
4/5 + (-1/2 - sqrt(3)*I/2)*(11*sqrt(5)/50 + 123/250)**(1/3) + 1/(25*(-1/2 - sqrt(3)*I/2)*(11*sqrt(5)/50 + 123/250)**(1/3))
# Out:
# 0.8 + (-0.5 - sqrt(3)*I/2)*(11*sqrt(5)/50 + 0.492)**0.333333333333333 + 1/((-12.5 - 25*sqrt(3)*I/2)*(11*sqrt(5)/50 + 0.492)**0.333333333333333)

# %%
math.ceil(4/5 + (-1/2 - sqrt(3)*I/2)*(11*sqrt(5)/50 + 123/250)**(1/3) + 1/(25*(-1/2 - sqrt(3)*I/2)*(11*sqrt(5)/50 + 123/250)**(1/3)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 math.ceil(4/5 + (-1/2 - sqrt(3)*I/2)*(11*sqrt(5)/50 + 123/250)**(1/3) + 1/(25*(-1/2 - sqrt(3)*I/2)*(11*sqrt(5)/50 + 123/250)**(1/3)))
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\sympy\core\expr.py:374, in Expr.__float__(self)
#     372     return float(result)
#     373 if result.is_number and result.as_real_imag()[1]:
# --> 374     raise TypeError("Cannot convert complex to float")
#     375 raise TypeError("Cannot convert expression to float")
#
# TypeError: Cannot convert complex to float

# %%
h
# Out:
# -log(x**2) + 12*cos(x)

# %%
h_diff = diff(h,x)

# %%
h_diff
# Out:
# -12*sin(x) - 2/x

# %%
solve(-12*sin(x)-12,x)
# Out:
# [-pi/2, 3*pi/2]

# %%
pi
# Out:
# pi

# %%
r = 5
r**2 * pi
# Out:
# 25*pi

# %% [markdown]
# ---
