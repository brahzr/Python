# %%
import pandas as pd

# %% [markdown]
# # XLSX

# %%
meat = pd.read_excel("C:/Users/Brahim/Desktop/meat.xlsx", sheet_name = "ALG")

# %%
meat.describe()
# Out:
#               Year       Meat  Meat, beef and buffalo   Meat, sheep and goat   \
# count    62.000000  61.000000                61.000000              62.000000
# mean   1991.500000   5.529865                 4.112464               5.390156
# std      18.041619   2.576046                 1.195827               1.641491
# min    1961.000000   1.529399                 2.163626               2.893097
# 25%    1976.250000   2.320916                 3.217553               3.655129
# 50%    1991.500000   7.242966                 3.956248               5.668588
# 75%    2006.750000   7.595921                 4.961605               6.372328
# max    2022.000000   8.255460                 6.645389               8.073443
#
#        Meat, Other        Fish
# count     62.000000  60.000000
# mean       0.414427   3.336388
# std        0.077226   1.148218
# min        0.317900   1.191288
# 25%        0.348937   2.288586
# 50%        0.375583   3.558892
# 75%        0.487086   4.171564
# ...

# %%
#rename
