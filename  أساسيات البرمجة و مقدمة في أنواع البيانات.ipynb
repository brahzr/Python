# %% [markdown]
# **Author:**
# Brahim Zirari <br>
# **Version:**
# Python 3.13.5 <br>
# **Topic:** <br>
# **This notebook provides a math cheat sheet in Python with practical examples of:** <br>
# -Coding Basics <br>
# -Introduction to Data Types <br>

# %% [markdown]
# ## Basics

# %% [markdown]
# **1. Read The error**

# %%
x = 5
Y = 7
print (x+y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 x = 5
#       2 Y = 7
# ----> 3 print (x+y)
#
# NameError: name 'y' is not defined

# %%
#use the debugger
# %debug
# Out:
# > c:\users\brahim\appdata\local\temp\ipykernel_11484\3135115894.py(3)<module>()
# ipdb>  x
# 5
# ipdb>  y
# *** NameError: name 'y' is not defined
# --KeyboardInterrupt--
#
# KeyboardInterrupt: Interrupted by user

# %%
y = 7 #correct y

# %%
print(x+y)
# Out:
# 12

# %% [markdown]
# **2. Overfitting** تغيير القيمة في التخزين و تحتفظ بآخر تحديث

# %%
x = -5

# %%
print (x+y)
# Out:
# 2

# %% [markdown]
# **3. Orginise your Code**

# %% [markdown]
# ---

# %% [markdown]
# ## Introduction to data types in Python

# %% [markdown]
# **1. integer عدد صحيح**

# %%
type(x)
# Out:
# int

# %% [markdown]
# **2. float  عشري**

# %%
z = 7.35

# %%
type(z)
# Out:
# float

# %% [markdown]
# **3. complex مركب**

# %%
e = 2+2j

# %%
type(e)
# Out:
# complex

# %% [markdown]
# **جمع عدد صحيح و عدد عشري**

# %%
print(x+z)
# Out:
# 2.3499999999999996

# %% [markdown]
# **جمع عدد صحيح و عدد مركب**

# %%
print(x+e)
# Out:
# (-3+2j)

# %% [markdown]
# **ضرب عدد صحيح و عدد مركب**

# %%
print(x*e)
# Out:
# (-10-10j)

# %% [markdown]
# **4. String نص**

# %%
name = "Ahmed"

# %%
type(name)
# Out:
# str

# %% [markdown]
# **4.1 Text Slicing**

# %%
name[2]
# Out:
# 'm'

# %%
name[4]
# Out:
# 'd'

# %%
#hme
name[1:4]
# Out:
# 'hme'

# %%
name[0:5:2]
# Out:
# 'Amd'

# %%
print(name[0],name[3])
# Out:
# A e

# %% [markdown]
# **4.2 Lower() & upper()**

# %%
name[3].lower()
# Out:
# 'e'

# %%
print(name[0:2],name[2].upper(),
      name[3],name[4].upper())
# Out:
# Ah M e D
